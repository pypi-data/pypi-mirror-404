# %% [markdown]
# Checking if the package exists

# %%
import aspen_pysys as ap
from aspen_pysys import *

ap.setup()
# Out:
# Aspen HYSYS

# %%
mixer = Hysys.get_module("MIX-101")
attached_feeds = mixer.attr("Attached Feeds")
print(attached_feeds)

feed1 = Hysys.get_module("Raw iBB Feed-2")
print(feed1)
# Out:
# ('FCA_Ex_Overhead-1', 'Raw iBB Feed-2')
# Raw iBB Feed-2

# %% [markdown]
# Stream data table (SDT)

# %%
Hysys._active_flowsheet.FluidPackage.PropertyPackageName
# Out:
# 'Aspen Properties (SRK)'

# %%
Hysys._active_flowsheet.FluidPackage.Components.Names
# Out:
# ('Hydrogen-Fluoride',
#  'Water',
#  'Isobutylbenzene',
#  '4-Isobutylacetophenone',
#  'Acetic-Anhydride',
#  'n-Butylbenzene',
#  'Acetyl-Fluoride',
#  'Acetic-Acid',
#  '4-Butylacetophenone',
#  'O-Xylene')

# %% [markdown]
# Debugging how unit sets work in HYSYS

# %%
# try:
# 	obj = HysysUtil._app.SimulationCases.Item("case")
# 	obj1 = obj.GetXMLForCase

# 	filepath = Path("IntSim_Team_10.hsc").absolute()
# 	# print(filepath)

# 	print(obj1)
# except com_error as e:
#     if obj1:
#         print(sig(obj1))
#         print(dir(obj1))

#     hresult, strerror, _, _ = e.args
#     print(win32api.FormatMessage(hresult))
#     # print(strerror)
# except Exception as e:
#     print(e)
# finally:
# 	if obj:
# 		print([x for x in dir(obj) if "_" not in x])
