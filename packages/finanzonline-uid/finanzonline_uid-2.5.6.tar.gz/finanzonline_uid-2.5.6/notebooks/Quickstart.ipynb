# %% [markdown]
# # check_zpool_status Quickstart
#
# Install the package (from PyPI or GitHub), then try the CLI and API examples below.

# %% [markdown]
# ## 1) Install latest from GitHub (default)

# %%
# update pip and setuptools
import sys

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools

# install check_zpool_status from GitHub (default)
# !{sys.executable} -m pip install --upgrade git+https://github.com/bitranox/check_zpool_status.git

# %% [markdown]
# ## Or: Install from PyPI (alternative)
# Uncomment and run the cell below if you prefer the PyPI release.

# %%
# !{sys.executable} -m pip install --upgrade check_zpool_status

# %% [markdown]
# ## 2) CLI: version and help

# %%
# !check_zpool_status --version
# !check_zpool_status --help
# !check_zpool_status info
# !check_zpool_status hello
# !check_zpool_status fail

# %% [markdown]
# ## 3) CLI fail without traceback

# %%
# !check_zpool_status fail

# %% [markdown]
# ## 4) CLI fail with traceback

# %%
# !check_zpool_status --traceback fail

# %% [markdown]
# ## 5) script fail without traceback

# %%
# !{sys.executable} -m check_zpool_status fail

# %% [markdown]
# ## 6) script fail with traceback

# %%
# !{sys.executable} -m check_zpool_status --traceback fail
