# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
import seaborn as sns
sns.set_style("ticks")
from vscodenb import set_vscode_theme, pqdm, prange, cpu_monitor

from vscodenb import cpu_monitor, pqdm, prange, set_vscode_theme
set_vscode_theme('dark')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9 from vscodenb import set_vscode_theme, pqdm, prange, cpu_monitor
#      11 from vscodenb import cpu_monitor, pqdm, prange, set_vscode_theme
# ---> 12 set_vscode_theme('dark')
#
# File ~/vscodenb/src/vscodenb/plot_theme.py:229, in set_vscode_theme(dark, cmap)
#     217 """
#     218 Set the default theme for the graph plotter.
#     219 The theme can be either 'dark' or 'light'. The default theme is autodetected.
#    (...)    225     _description_
#     226 """
#     228 if dark not in [None, True, False]:
# --> 229     raise ValueError("dark parameter must be None, True, or False.")
#     231 with suppress_plotting_output():
#     233     set_matplotlib_formats('retina', 'png')
#
# ValueError: dark parameter must be None, True, or False.
