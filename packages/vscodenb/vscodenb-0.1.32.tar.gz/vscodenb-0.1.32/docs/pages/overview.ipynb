# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %%
#| echo: false

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **vscodenb** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add vscodenb
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group vscodenb
# ```
#
# ## pip
#
# ```bash
# pip install vscodenb
# ```
#
# :::

# %% [markdown]
# ::: {.callout-tip}
#
# To enable automatic theme detection, you must add the following setting to your vscode `settings.json`:
#
# ```json
# "jupyter.themeMatplotlibPlots": true,
# ```
#
# You can open `settings.json` from the command palette (Cmd-Shift-p) by typing "user settings" and select "Preferences: Open User Settings (JSON)".
#
# :::

# %%
from numpy.random import random
import matplotlib.pyplot as plt
import time

# %%
#| output: false

plt.rcParams['figure.figsize'] = (5, 3.7)

# %% [markdown]
# ## Plot theme

# %%
import vscodenb
vscodenb.set_vscode_theme()

plt.scatter(random(10), random(10)) ;
# Out:
# <style>
# .widget-label,
# .widget-html,
# .widget-button,
# .widget-dropdown,
# .widget-text,
# .widget-textarea {
#     color: #CCCCCC !important;  /* Set to desired color */
#     font-size: 10px !important;      /* Font size */
#
# }
# div.widget-html-content > progress { /* Outer container */
#     height: 10px !important;
#
# }
# div.jp-OutputArea-output td.output_html { /* tqdm HTML output area */
#     height: 5px !important;
# }
# div.progress { /* Jupyter Notebook (classic) */
#     height: 5px !important;
#     min-height: 5px !important;
#     margin-top: 12px !important;
# }
# div.progress-bar { /* Inner bar */
#     height: 5px !important;
#     min-height: 5px !important;
#     line-height: 5px !important;
#     color: 'white' !important;
#     padding-bottom: 0px !important;
# }
# </style>
# Overriding theme from NOTEBOOK_THEME environment variable. <ipykernel.iostream.OutStream object at 0x1078054b0>
#         <style>
#         .cell-output-ipywidget-background {
#             background-color: transparent !important;
#         }
#        .jp-OutputArea-output {
#            background-color: transparent;
#         }
#         /*
#         :root {
#             --jp-widgets-color: var(--vscode-editor-foreground);
#             --jp-widgets-font-size: var(--vscode-editor-font-size);
#         }
#         */
#         /* tqdm styling: */
#         .widget-label,
#         .widget-html,
#         .widget-button,
#         .widget-dropdown,
#         .widget-text,
#         .widget-textarea {
#             font-size: 10px !important;      /* Font size */
#         }
#         div.widget-html-content > progress { /* Outer container */
#             height: 10px !important;
#
#         }
#         div.jp-OutputArea-output td.output_html { /* tqdm HTML output area */
#             height: 5px !important;
#         }
#         div.progress { /* Jupyter Notebook (classic) */
#             height: 5px !important;
#             min-height: 5px !important;
#             margin-top: 12px !important;
#         }
#         div.progress-bar { /* inner bar */
#             height: 5px !important;
#             min-height: 5px !important;
#             line-height: 5px !important;
#             color: 'white' !important;
#             padding-bottom: 0px !important;
#         }
#         </style>

# %% [markdown]
# See a full demo at [here](plot_theme.ipynb).

# %% [markdown]
# ## Resource monitor utils

# %%
import vscodenb # importing vscodenb automatically enables monitoring

# %%
# %%monitor -p
#
# time.sleep(3)
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style=""><div style="margin-bottom: 6px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 64.0% avg">
#                             <div style="width: 64.01428571428572%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 63.6% avg">
#                             <div style="width: 63.614285714285714%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 40.1% avg">
#                             <div style="width: 40.05714285714286%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 41.7% avg">
#                             <div style="width: 41.65714285714286%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 31.4% avg">
#                             <div style="width: 31.414285714285715%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 21.9% avg">
#                             <div style="width: 21.885714285714283%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 9.2% avg">
#                             <div style="width: 9.171428571428573%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 5.9% avg">
#                             <div style="width: 5.942857142857142%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 8: 3.7% avg">
#                             <div style="width: 3.685714285714286%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 9: 1.7% avg">
#                             <div style="width: 1.6714285714285713%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# See a full demo at [here](cpu_monitoring.ipynb).

# %% [markdown]
# ## Less intrusive progress bars

# %%
from vscodenb import pqdm, prange

for i in prange(10, persist=True):
    time.sleep(0.1)
# Out:
#         <div style="font-family: monospace; font-size: 10px; padding: 0px 10px 5px 10px; display: flex; align-items: center; gap: 1ch;">
#             <div style="white-space: nowrap; flex-shrink: 0;">
#                  100% | 0 s
#             </div>
#             <div style="flex: 1; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 100%; height: 100%; background: #666666; transition: width 0.3s;"></div>
#             </div>
#         </div>

# %%
for i in pqdm([1, 2, 3], persist=True):
    time.sleep(0.1)
# Out:
#         <div style="font-family: monospace; font-size: 10px; padding: 0px 10px 5px 10px; display: flex; align-items: center; gap: 1ch;">
#             <div style="white-space: nowrap; flex-shrink: 0;">
#                  100% | 0 s
#             </div>
#             <div style="flex: 1; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 100%; height: 100%; background: #666666; transition: width 0.3s;"></div>
#             </div>
#         </div>

# %% [markdown]
# See a full demo at [here](progress.ipynb).

# %% [markdown]
# ## SLURM cell magic
#
# Run a single cell as a SLURM job:

# %%
# %%slurm
#
# s = "Variable values updated in the slurm job are automatically transferred back to the notebook!"
# Out:
# Not running on SLURM cluster.

# %%
print(f"It works: {s}")
# Out:
# It works: Variable values updated in the slurm job are automatically transferred back to the notebook!

# %% [markdown]
# See a full demo at [here](slurm_magic.ipynb).
