# %%
import numpy as np
from numpy.typing import NDArray
import atdata
from atdata.local import LocalDatasetEntry, S3DataStore, Index
import webdataset as wds

# %%
@atdata.packable
class TestSample:
    """TODO Hello."""
    image: NDArray
    label: int

# %%
x = TestSample(
    image = np.random.normal( size = (224, 224) ),
    label = 1,
)
