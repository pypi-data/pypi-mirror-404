# %% [markdown]
# # btx_lib_mail Quickstart
#
# Install the package (from PyPI or GitHub), then try the CLI and API examples below.

# %% [markdown]
# ## 1) Install latest from GitHub (default)

# %%
# update pip and setuptools
import sys

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools

# install btx_lib_mail from GitHub (default)
# !{sys.executable} -m pip install --upgrade git+https://github.com/bitranox/btx_lib_mail.git

# %% [markdown]
# ## Or: Install from PyPI (alternative)
# Uncomment and run the cell below if you prefer the PyPI release.

# %%
# !{sys.executable} -m pip install --upgrade btx_lib_mail

# %% [markdown]
# ## 2) CLI: version and help

# %%
# !btx_lib_mail --version
# !btx_lib_mail --help
# !btx_lib_mail info
# !btx_lib_mail hello
# !btx_lib_mail fail

# %% [markdown]
# ## 3) CLI fail without traceback

# %%
# !btx_lib_mail fail

# %% [markdown]
# ## 4) CLI fail with traceback

# %%
# !btx_lib_mail --traceback fail

# %% [markdown]
# ## 5) script fail without traceback

# %%
# !{sys.executable} -m btx_lib_mail fail

# %% [markdown]
# ## 6) script fail with traceback

# %%
# !{sys.executable} -m btx_lib_mail --traceback fail
